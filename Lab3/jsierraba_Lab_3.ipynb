# %% [markdown]
# **Link de LinkedIn:** https://www.linkedin.com/feed/update/urn%3Ali%3AugcPost%3A7037967459496210432/?midToken=AQFxtCNESBcJ2g&midSig=2dmuYIHtWyKWE1&trk=eml-email_notification_single_content_processing_complete_01-notifications-1-null&trkEmail=eml-email_notification_single_content_processing_complete_01-notifications-1-null-null-i7jqg7%7Eleura4k8%7Ewk-null-voyagerOffline

# %% [markdown]
# ![Screenshot 2023-03-04 212112.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-03-04 211905.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-03-04 212034.png](data:image/png;base64,...)
